# %% [markdown]
# # Fetch Target Varible
# Data obtained from en.tutiempo.net have only X values ,however the respective Y values i.e AQI for the years b/w 2013-2018 we are getting from weathermap.com (a third party API)
#
# Since the target values obtained is AQI for 24 hrs format ,we are taking daily avg f it respective to X varible values.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# def avg_data(year):
#     temp_i=0
#     average =[]
#     url = "Data\\AQI\\aqi{}.csv".format(year)
#
#     #Each iteration we wanna fetch first 24 records i.e 24 hrs/one day data from CSV file
#     for row in pd.read_csv(url ,chunksize =24):
#             add_var = 0
#             avg =0.0
#             data = []
#             #print(rows)
#             df = pd.DataFrame(data =row)
#             for index ,row in df.iterrows():
#                 data.append(row['PM2.5'])
#             for i in data:
#                 if type(i) is float or type(i) is int:
#                     add_var = add_var+i
#                 elif type(i) is str:
#                     if i!='NoData' and i!='PwrFail' and i!='---' and i!="InVld" :
#                         temp = float(i)
#                         add_var = add_var + temp
#             avg = add_var/24
#             temp_i = temp_i +1
#
#             average.append(avg)
#     return average

# %%
if __name__ =="__main__":
    for i in range(2013,2019):
        lst =avg_data(i)
        val = " {} data".format(i)
        print(val)
        plt.plot(lst ,label = val)
        plt.legend(loc = 'upper right')
        plt.xlabel('Day')
        plt.ylabel('PM 2.5')
        plt.show()
# Out:
#  2013 data
#  2014 data
#  2015 data
#  2016 data
#  2017 data
#  2018 data

# %%
def avg_data_2013(): 
    temp_i=0
    average =[]
    url = "Data\\AQI\\aqi2013.csv"
    
    #Each iteration we wanna fetch first 24 records i.e 24 hrs/one day data from CSV file
    for row in pd.read_csv(url ,chunksize =24):
            add_var = 0
            avg =0.0
            data = []
            #print(rows)
            df = pd.DataFrame(data =row) 
            for index ,row in df.iterrows():
                data.append(row['PM2.5'])
            for i in data:
                if type(i) is float or type(i) is int:
                    add_var = add_var+i
                elif type(i) is str:
                    if i!='NoData' and i!='PwrFail' and i!='---' and i!="InVld" :
                        temp = float(i)
                        add_var = add_var + temp
            avg = add_var/24
            temp_i = temp_i +1
            
            average.append(avg)
    return average

# %%
def avg_data_2014(): 
    temp_i=0
    average =[]
    url = "Data\\AQI\\aqi2014.csv"
    
    #Each iteration we wanna fetch first 24 records i.e 24 hrs/one day data from CSV file
    for row in pd.read_csv(url ,chunksize =24):
            add_var = 0
            avg =0.0
            data = []
            #print(rows)
            df = pd.DataFrame(data =row) 
            for index ,row in df.iterrows():
                data.append(row['PM2.5'])
            for i in data:
                if type(i) is float or type(i) is int:
                    add_var = add_var+i
                elif type(i) is str:
                    if i!='NoData' and i!='PwrFail' and i!='---' and i!="InVld" :
                        temp = float(i)
                        add_var = add_var + temp
            avg = add_var/24
            temp_i = temp_i +1
            
            average.append(avg)
    return average

# %%
def avg_data_2015(): 
    temp_i=0
    average =[]
    url = "Data\\AQI\\aqi2015.csv"
    
    #Each iteration we wanna fetch first 24 records i.e 24 hrs/one day data from CSV file
    for row in pd.read_csv(url ,chunksize =24):
            add_var = 0
            avg =0.0
            data = []
            #print(rows)
            df = pd.DataFrame(data =row) 
            for index ,row in df.iterrows():
                data.append(row['PM2.5'])
            for i in data:
                if type(i) is float or type(i) is int:
                    add_var = add_var+i
                elif type(i) is str:
                    if i!='NoData' and i!='PwrFail' and i!='---' and i!="InVld" :
                        temp = float(i)
                        add_var = add_var + temp
            avg = add_var/24
            temp_i = temp_i +1
            
            average.append(avg)
    return average

# %%
def avg_data_2016(): 
    temp_i=0
    average =[]
    url = "Data\\AQI\\aqi2016.csv"
    
    #Each iteration we wanna fetch first 24 records i.e 24 hrs/one day data from CSV file
    for row in pd.read_csv(url ,chunksize =24):
            add_var = 0
            avg =0.0
            data = []
            #print(rows)
            df = pd.DataFrame(data =row) 
            for index ,row in df.iterrows():
                data.append(row['PM2.5'])
            for i in data:
                if type(i) is float or type(i) is int:
                    add_var = add_var+i
                elif type(i) is str:
                    if i!='NoData' and i!='PwrFail' and i!='---' and i!="InVld" :
                        temp = float(i)
                        add_var = add_var + temp
            avg = add_var/24
            temp_i = temp_i +1
            
            average.append(avg)
    return average

# %%
def avg_data_2017(): 
    temp_i=0
    average =[]
    url = "Data\\AQI\\aqi2017.csv"
    
    #Each iteration we wanna fetch first 24 records i.e 24 hrs/one day data from CSV file
    for row in pd.read_csv(url ,chunksize =24):
            add_var = 0
            avg =0.0
            data = []
            #print(rows)
            df = pd.DataFrame(data =row) 
            for index ,row in df.iterrows():
                data.append(row['PM2.5'])
            for i in data:
                if type(i) is float or type(i) is int:
                    add_var = add_var+i
                elif type(i) is str:
                    if i!='NoData' and i!='PwrFail' and i!='---' and i!="InVld" :
                        temp = float(i)
                        add_var = add_var + temp
            avg = add_var/24
            temp_i = temp_i +1
            
            average.append(avg)
    return average

# %%
if __name__=="__main__":
    lst2013=avg_data_2013()
    lst2014=avg_data_2014()
    lst2015=avg_data_2015()
    lst2016=avg_data_2016()
    lst2017=avg_data_2017()
    #lst2018=avg_data_2018()
    plt.plot(lst2013,label="2013 data")
    plt.plot(lst2014,label="2014 data")
    plt.plot(lst2015,label="2015 data")
    plt.plot(lst2016,label="2016 data")
    plt.xlabel('Day')
    plt.ylabel('PM 2.5')
    plt.legend(loc='upper right')
    plt.show()
